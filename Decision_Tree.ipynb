# %% [markdown]
# # Assignment # 2 <br>Information gain as spiting criterion

# %%
from sklearn import datasets
import pandas as pd
import numpy as np

# %%
conda install pydot
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Iris Dataset

# %%
iris = datasets.load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
X.head(3)
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2

# %%
y = pd.get_dummies(y)

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## Information gain as criterion, and maximum depth of the tree = 4

# %%
dt = DecisionTreeClassifier(criterion="entropy", max_depth=4)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=4,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.tree import export_graphviz
from sklearn.externals.six import StringIO 
from IPython.display import Image 
from pydot import graph_from_dot_data

# %% [markdown]
# ## Visualizing

# %%
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data, feature_names=iris.feature_names)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# #### Prediction

# %%
y_pred = dt.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9736842105263158

# %% [markdown]
# # Wine Dataset

# %%
wine = datasets.load_wine()
X = pd.DataFrame(wine.data, columns=wine.feature_names)
y = pd.Categorical.from_codes(wine.target, wine.target_names)

# %%
X.head(3)
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
#
#    od280/od315_of_diluted_wines  proline
# 0                          3.92   1065.0
# 1                          3.40   1050.0
# 2                          3.17   1185.0

# %%
y = pd.get_dummies(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## Information gain as criterion, and maximum depth of the tree = 1

# %%
dt = DecisionTreeClassifier(criterion="entropy", max_depth=1)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=1,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %% [markdown]
# ## Visualizing The Tree

# %%
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data, feature_names=wine.feature_names)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# #### Prediction

# %%
y_pred = dt.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9111111111111111

# %% [markdown]
# # Breast Cancer Dataset

# %%
breast_cancer = datasets.load_breast_cancer()
X = pd.DataFrame(breast_cancer.data, columns=breast_cancer.feature_names)
y = pd.Categorical.from_codes(breast_cancer.target, breast_cancer.target_names)

# %%
X.head(3)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38           122.8     1001.0          0.11840
# 1        20.57         17.77           132.9     1326.0          0.08474
# 2        19.69         21.25           130.0     1203.0          0.10960
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# 0                 0.07871  ...         25.38          17.33            184.6
# 1                 0.05667  ...         24.99          23.41            158.8
# 2                 0.05999  ...         23.57          25.53            152.5
#
#    worst area  worst smoothness  worst compactness  worst concavity  \
# ...

# %%
y = pd.get_dummies(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %% [markdown]
# ## Information gain as criterion, and maximum depth of the tree = 2

# %%
dt = DecisionTreeClassifier(criterion="entropy", max_depth=2)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='entropy', max_depth=2,
#                        max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort=False,
#                        random_state=None, splitter='best')

# %%
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data, feature_names=breast_cancer.feature_names)
(graph, ) = graph_from_dot_data(dot_data.getvalue())
Image(graph.create_png())

# %% [markdown]
# #### Prediction

# %%
y_pred = dt.predict(X_test)

# %% [markdown]
# ## Accuracy

# %%
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.9370629370629371
